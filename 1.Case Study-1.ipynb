# %% [markdown]
# # Case Study

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/91701/Desktop/Dataset/nchs.csv")

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %% [markdown]
# <font color='red'># Attributes and underlying data</font>

# %%
data.index # The index (row labels) of the DataFrame.
# Out:
# RangeIndex(start=0, stop=10296, step=1)

# %%
data.columns # 	The column labels of the DataFrame.
# Out:
# Index(['Year', '113 Cause Name', 'Cause Name', 'State', 'Deaths',
#        'Age-adjusted Death Rate'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 6

# %%
data.dtypes # Return the dtypes in the DataFrame.
# Out:
# Year                         int64
# 113 Cause Name              object
# Cause Name                  object
# State                       object
# Deaths                       int64
# Age-adjusted Death Rate    float64
# dtype: object

# %%
type(data.dtypes) # it is form of series
# Out:
# pandas.core.series.Series

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10296 non-null  int64
#  1   113 Cause Name           10296 non-null  object
#  2   Cause Name               10296 non-null  object
#  3   State                    10296 non-null  object
#  4   Deaths                   10296 non-null  int64
#  5   Age-adjusted Death Rate  10296 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 482.8+ KB

# %%
help(data.info) # Print a concise summary of a DataFrame.
# Out:
# Help on method info in module pandas.core.frame:
#
# info(verbose: 'bool | None' = None, buf: 'WriteBuffer[str] | None' = None, max_cols: 'int | None' = None, memory_usage: 'bool | str | None' = None, show_counts: 'bool | None' = None, null_counts: 'bool | None' = None) -> 'None' method of pandas.core.frame.DataFrame instance
#     Print a concise summary of a DataFrame.
#
#     This method prints information about a DataFrame including
#     the index dtype and columns, non-null values and memory usage.
#
#     Parameters
#     ----------
#     verbose : bool, optional
#         Whether to print the full summary. By default, the setting in
#         ``pandas.options.display.max_info_columns`` is followed.
#     buf : writable buffer, defaults to sys.stdout
#         Where to send the output. By default, the output is printed to
#         sys.stdout. Pass a writable buffer if you need to further process
#         the output.    max_cols : int, optional
# ...

# %%
data.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Columns: 6 entries, Year to Age-adjusted Death Rate
# dtypes: float64(1), int64(2), object(3)
# memory usage: 482.8+ KB

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10296 non-null  int64
#  1   113 Cause Name           10296 non-null  object
#  2   Cause Name               10296 non-null  object
#  3   State                    10296 non-null  object
#  4   Deaths                   10296 non-null  int64
#  5   Age-adjusted Death Rate  10296 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.5 MB

# %%
help(data.select_dtypes)
# Out:
# Help on method select_dtypes in module pandas.core.frame:
#
# select_dtypes(include=None, exclude=None) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Return a subset of the DataFrame's columns based on the column dtypes.
#
#     Parameters
#     ----------
#     include, exclude : scalar or list-like
#         A selection of dtypes or strings to be included/excluded. At least
#         one of these parameters must be supplied.
#
#     Returns
#     -------
#     DataFrame
#         The subset of the frame including the dtypes in ``include`` and
#         excluding the dtypes in ``exclude``.
#
#     Raises
#     ------
#     ValueError
#         * If both of ``include`` and ``exclude`` are empty
#         * If ``include`` and ``exclude`` have overlapping elements
#         * If any kind of string dtype is passed in.
#
#     See Also
#     --------
#     DataFrame.dtypes: Return Series with the data type of each column.
#
#     Notes
#     -----
# ...

# %%
# Return a subset of the DataFrame's columns based on the column dtypes.

# %%
data.select_dtypes(include = ['int64'])
# Out:
#        Year  Deaths
# 0      2016    2755
# 1      2016     439
# 2      2016    4010
# 3      2016    1604
# 4      2016   13213
# ...     ...     ...
# 10291  2003     273
# 10292  2002     289
# 10293  2001     272
# 10294  2000     245
# 10295  1999     258
#
# [10296 rows x 2 columns]

# %%
data.select_dtypes(exclude = ['int64'])
# Out:
#                                           113 Cause Name  \
# 0      Accidents (unintentional injuries) (V01-X59,Y8...
# 1      Accidents (unintentional injuries) (V01-X59,Y8...
# 2      Accidents (unintentional injuries) (V01-X59,Y8...
# 3      Accidents (unintentional injuries) (V01-X59,Y8...
# 4      Accidents (unintentional injuries) (V01-X59,Y8...
# ...                                                  ...
# 10291  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama                     55.5
# 1      Unintentional injuries      Alaska                     63.1
# 2      Unintentional injuries     Arizona                     54.2
# ...

# %%
data.select_dtypes(include=['float64'], exclude=['int64'])
# Out:
#        Age-adjusted Death Rate
# 0                         55.5
# 1                         63.1
# 2                         54.2
# 3                         51.8
# 4                         32.0
# ...                        ...
# 10291                     55.1
# 10292                     58.1
# 10293                     55.5
# 10294                     50.8
# 10295                     52.8
#
# [10296 rows x 1 columns]

# %%
type(data.select_dtypes)
# Out:
# method

# %%
data.values
# Out:
# array([[2016, 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#         'Unintentional injuries', 'Alabama', 2755, 55.5],
#        [2016, 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#         'Unintentional injuries', 'Alaska', 439, 63.1],
#        [2016, 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#         'Unintentional injuries', 'Arizona', 4010, 54.2],
#        ...,
#        [2001, 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#         'Unintentional injuries', 'Wyoming', 272, 55.5],
#        [2000, 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#         'Unintentional injuries', 'Wyoming', 245, 50.8],
#        [1999, 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#         'Unintentional injuries', 'Wyoming', 258, 52.8]], dtype=object)

# %%
type(data.values) # Return a Numpy representation of the DataFrame.
# Out:
# numpy.ndarray

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=10296, step=1),
#  Index(['Year', '113 Cause Name', 'Cause Name', 'State', 'Deaths',
#         'Age-adjusted Death Rate'],
#        dtype='object')]

# %%
type(data.axes) # Return a list representing the axes of the DataFrame
# Out:
# list

# %%
data.ndim
# Out:
# 2

# %%
type(data.ndim) # Return an int representing the number of axes / array dimensions.
# Out:
# int

# %%
data.size # Return an int representing the number of elements in this object.
# Out:
# 61776

# %%
data.shape # Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (10296, 6)

# %%
10296 * 6 # So total records
# Out:
# 61776

# %%
help(data.memory_usage)
# Out:
# Help on method memory_usage in module pandas.core.frame:
#
# memory_usage(index: 'bool' = True, deep: 'bool' = False) -> 'Series' method of pandas.core.frame.DataFrame instance
#     Return the memory usage of each column in bytes.
#
#     The memory usage can optionally include the contribution of
#     the index and elements of `object` dtype.
#
#     This value is displayed in `DataFrame.info` by default. This can be
#     suppressed by setting ``pandas.options.display.memory_usage`` to False.
#
#     Parameters
#     ----------
#     index : bool, default True
#         Specifies whether to include the memory usage of the DataFrame's
#         index in returned Series. If ``index=True``, the memory usage of
#         the index is the first item in the output.
#     deep : bool, default False
#         If True, introspect the data deeply by interrogating
#         `object` dtypes for system-level memory consumption, and include
#         it in the returned values.
#
#     Returns
# ...

# %%
data.memory_usage()
# Out:
# Index                        132
# Year                       82368
# 113 Cause Name             82368
# Cause Name                 82368
# State                      82368
# Deaths                     82368
# Age-adjusted Death Rate    82368
# dtype: int64

# %%
data.memory_usage(index = False)
# Out:
# Year                       82368
# 113 Cause Name             82368
# Cause Name                 82368
# State                      82368
# Deaths                     82368
# Age-adjusted Death Rate    82368
# dtype: int64

# %%
data.memory_usage(deep = True)
# Out:
# Index                         132
# Year                        82368
# 113 Cause Name             978120
# Cause Name                 710424
# State                      676962
# Deaths                      82368
# Age-adjusted Death Rate     82368
# dtype: int64

# %%
type(data.memory_usage())
# Out:
# pandas.core.series.Series

# %%
type(data.memory_usage(deep = True))
# Out:
# pandas.core.series.Series

# %%
# Return the memory usage of each column in bytes.

# %%
data.empty # Indicator whether Series/DataFrame is empty.
# Out:
# False

# %% [markdown]
# <font color = 'red'> # Conversion

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
help(data.astype)
# Out:
# Help on method astype in module pandas.core.generic:
#
# astype(dtype, copy: 'bool_t' = True, errors: 'IgnoreRaise' = 'raise') -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Cast a pandas object to a specified dtype ``dtype``.
#
#     Parameters
#     ----------
#     dtype : data type, or dict of column name -> data type
#         Use a numpy.dtype or Python type to cast entire pandas object to
#         the same type. Alternatively, use {col: dtype, ...}, where col is a
#         column label and dtype is a numpy.dtype or Python type to cast one
#         or more of the DataFrame's columns to column-specific types.
#     copy : bool, default True
#         Return a copy when ``copy=True`` (be very careful setting
#         ``copy=False`` as changes to values then may propagate to other
#         pandas objects).
#     errors : {'raise', 'ignore'}, default 'raise'
#         Control raising of exceptions on invalid data for provided dtype.
#
# ...

# %%
data.dtypes
# Out:
# Year                         int64
# 113 Cause Name              object
# Cause Name                  object
# State                       object
# Deaths                       int64
# Age-adjusted Death Rate    float64
# dtype: object

# %%
data['Year'] = data['Year'].astype('int32').dtype

# %%
data['Year']
# Out:
# 0        int32
# 1        int32
# 2        int32
# 3        int32
# 4        int32
#          ...
# 10291    int32
# 10292    int32
# 10293    int32
# 10294    int32
# 10295    int32
# Name: Year, Length: 10296, dtype: object

# %%
data.dtypes
# Out:
# Year                        object
# 113 Cause Name              object
# Cause Name                  object
# State                       object
# Deaths                       int64
# Age-adjusted Death Rate    float64
# dtype: object

# %%
# Cast a pandas object to a specified dtype dtype.

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
help(data.convert_dtypes)
# Out:
# Help on method convert_dtypes in module pandas.core.generic:
#
# convert_dtypes(infer_objects: 'bool_t' = True, convert_string: 'bool_t' = True, convert_integer: 'bool_t' = True, convert_boolean: 'bool_t' = True, convert_floating: 'bool_t' = True) -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Convert columns to best possible dtypes using dtypes supporting ``pd.NA``.
#
#     .. versionadded:: 1.0.0
#
#     Parameters
#     ----------
#     infer_objects : bool, default True
#         Whether object dtypes should be converted to the best possible types.
#     convert_string : bool, default True
#         Whether object dtypes should be converted to ``StringDtype()``.
#     convert_integer : bool, default True
#         Whether, if possible, conversion can be done to integer extension types.
#     convert_boolean : bool, defaults True
#         Whether object dtypes should be converted to ``BooleanDtypes()``.
#     convert_floating : bool, defaults True
# ...

# %%
data1 = data.convert_dtypes()

# %%
data1
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
data1.dtypes
# Out:
# Year                         Int64
# 113 Cause Name              string
# Cause Name                  string
# State                       string
# Deaths                       Int64
# Age-adjusted Death Rate    Float64
# dtype: object

# %%
#  Convert the DataFrame to use best possible dtypes.

# %%
data.convert_dtypes(infer_objects=True).dtypes # See instead of object we get string
# Out:
# Year                         Int64
# 113 Cause Name              string
# Cause Name                  string
# State                       string
# Deaths                       Int64
# Age-adjusted Death Rate    Float64
# dtype: object

# %%
data.convert_dtypes(infer_objects=False).dtypes
# Out:
# Year                         Int64
# 113 Cause Name              string
# Cause Name                  string
# State                       string
# Deaths                       Int64
# Age-adjusted Death Rate    Float64
# dtype: object

# %%
help(data.infer_objects)
# Out:
# Help on method infer_objects in module pandas.core.generic:
#
# infer_objects() -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Attempt to infer better dtypes for object columns.
#
#     Attempts soft conversion of object-dtyped
#     columns, leaving non-object and unconvertible
#     columns unchanged. The inference rules are the
#     same as during normal Series/DataFrame construction.
#
#     Returns
#     -------
#     converted : same type as input object
#
#     See Also
#     --------
#     to_datetime : Convert argument to datetime.
#     to_timedelta : Convert argument to timedelta.
#     to_numeric : Convert argument to numeric type.
#     convert_dtypes : Convert argument to best possible dtype.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({"A": ["a", 1, 2, 3]})
#     >>> df = df.iloc[1:]
#     >>> df
#        A
#     1  1
#     2  2
#     3  3
#
#     >>> df.dtypes
#     A    object
#     dtype: object
#
# ...

# %%
data.dtypes
# Out:
# Year                         int64
# 113 Cause Name              object
# Cause Name                  object
# State                       object
# Deaths                       int64
# Age-adjusted Death Rate    float64
# dtype: object

# %%
data.infer_objects().dtypes # Attempt to infer better dtypes for object columns.
# Out:
# Year                         int64
# 113 Cause Name              object
# Cause Name                  object
# State                       object
# Deaths                       int64
# Age-adjusted Death Rate    float64
# dtype: object

# %%
help(data.copy)
# Out:
# Help on method copy in module pandas.core.generic:
#
# copy(deep: 'bool_t | None' = True) -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Make a copy of this object's indices and data.
#
#     When ``deep=True`` (default), a new object will be created with a
#     copy of the calling object's data and indices. Modifications to
#     the data or indices of the copy will not be reflected in the
#     original object (see notes below).
#
#     When ``deep=False``, a new object will be created without copying
#     the calling object's data or index (only references to the data
#     and index are copied). Any changes to the data of the original
#     will be reflected in the shallow copy (and vice versa).
#
#     Parameters
#     ----------
#     deep : bool, default True
#         Make a deep copy, including a copy of the data and the indices.
#         With ``deep=False`` neither the indices nor the data are copied.
#
#     Returns
#     -------
# ...

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data1 = data.copy(deep = True)

# %%
data1.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data1.at[0,'Deaths']
# Out:
# 2755

# %%
data1.at[0,'Deaths'] = 10000

# %%
data1.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama   10000                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.head() # See original value is not changed
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data2 = data.copy(deep = False)

# %%
data2.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data2.at[0,'Deaths'] = 1000000

# %%
data2.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State   Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama  1000000                     55.5
# 1  Unintentional injuries      Alaska      439                     63.1
# 2  Unintentional injuries     Arizona     4010                     54.2
# 3  Unintentional injuries    Arkansas     1604                     51.8
# 4  Unintentional injuries  California    13213                     32.0

# %%
data.head() # see original also changed
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State   Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama  1000000                     55.5
# 1  Unintentional injuries      Alaska      439                     63.1
# 2  Unintentional injuries     Arizona     4010                     54.2
# 3  Unintentional injuries    Arkansas     1604                     51.8
# 4  Unintentional injuries  California    13213                     32.0

# %%
# Make a copy of this object's indices and data.

# %% [markdown]
# <font color = 'red'> # Indexing Iteration

# %%
data.head() #Return the first n rows.
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State   Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama  1000000                     55.5
# 1  Unintentional injuries      Alaska      439                     63.1
# 2  Unintentional injuries     Arizona     4010                     54.2
# 3  Unintentional injuries    Arkansas     1604                     51.8
# 4  Unintentional injuries  California    13213                     32.0

# %%
help(data.at)
# Out:
# Help on _AtIndexer in module pandas.core.indexing object:
#
# class _AtIndexer(_ScalarAccessIndexer)
#  |  Access a single value for a row/column label pair.
#  |
#  |  Similar to ``loc``, in that both provide label-based lookups. Use
#  |  ``at`` if you only need to get or set a single value in a DataFrame
#  |  or Series.
#  |
#  |  Raises
#  |  ------
#  |  KeyError
#  |      * If getting a value and 'label' does not exist in a DataFrame or
#  |          Series.
#  |  ValueError
#  |      * If row/column label pair is not a tuple or if any label from
#  |          the pair is not a scalar for DataFrame.
#  |      * If label is list-like (*excluding* NamedTuple) for Series.
#  |
#  |  See Also
#  |  --------
#  |  DataFrame.at : Access a single value for a row/column pair by label.
#  |  DataFrame.iat : Access a single value for a row/column pair by integer
#  |      position.
#  |  DataFrame.loc : Access a group of rows and columns by label(s).
# ...

# %%
data.at[3,'State'] #  Access a single value for a row/column label pair.
# Out:
# 'Arkansas'

# %%
help(data.iat)
# Out:
# Help on _iAtIndexer in module pandas.core.indexing object:
#
# class _iAtIndexer(_ScalarAccessIndexer)
#  |  Access a single value for a row/column pair by integer position.
#  |
#  |  Similar to ``iloc``, in that both provide integer-based lookups. Use
#  |  ``iat`` if you only need to get or set a single value in a DataFrame
#  |  or Series.
#  |
#  |  Raises
#  |  ------
#  |  IndexError
#  |      When integer position is out of bounds.
#  |
#  |  See Also
#  |  --------
#  |  DataFrame.at : Access a single value for a row/column label pair.
#  |  DataFrame.loc : Access a group of rows and columns by label(s).
#  |  DataFrame.iloc : Access a group of rows and columns by integer position(s).
#  |
#  |  Examples
#  |  --------
#  |  >>> df = pd.DataFrame([[0, 2, 3], [0, 4, 1], [10, 20, 30]],
#  |  ...                   columns=['A', 'B', 'C'])
#  |  >>> df
#  |      A   B   C
#  |  0   0   2   3
#  |  1   0   4   1
#  |  2  10  20  30
#  |
# ...

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State   Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama  1000000                     55.5
# 1  Unintentional injuries      Alaska      439                     63.1
# 2  Unintentional injuries     Arizona     4010                     54.2
# 3  Unintentional injuries    Arkansas     1604                     51.8
# 4  Unintentional injuries  California    13213                     32.0

# %%
data.iat[2,4] # Access a single value for a row/column pair by integer position.
# Out:
# 4010

# %%
# columns are also considered as 0's and 1's

# %%
help(data.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - An alignable boolean Series. The index of the key will be aligned before
#  |    masking.
# ...

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State   Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama  1000000                     55.5
# 1  Unintentional injuries      Alaska      439                     63.1
# 2  Unintentional injuries     Arizona     4010                     54.2
# 3  Unintentional injuries    Arkansas     1604                     51.8
# 4  Unintentional injuries  California    13213                     32.0

# %%
data.loc[3] #  Single label. Note this returns the row as a Series.
# Out:
# Year                                                                    2016
# 113 Cause Name             Accidents (unintentional injuries) (V01-X59,Y8...
# Cause Name                                            Unintentional injuries
# State                                                               Arkansas
# Deaths                                                                  1604
# Age-adjusted Death Rate                                                 51.8
# Name: 3, dtype: object

# %%
data.loc[[3,4]] #  List of labels. Note using ``[[]]`` returns a DataFrame.
# Out:
#    Year                                     113 Cause Name  \
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.loc[3,'Year'] #  Single label for row and column
# Out:
# 2016

# %%
data.loc[2:4,'Deaths'] # Slice with labels for row and single label for column.
# Out:
# 2     4010
# 3     1604
# 4    13213
# Name: Deaths, dtype: int64

# %%
data.loc[data['Deaths'] > 15000]
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 52     2016                                         All Causes
# 53     2015                                         All Causes
# 54     2014                                         All Causes
# 55     2013                                         All Causes
# ...     ...                                                ...
# 10172  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10173  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10174  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10175  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10176  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name          State   Deaths  Age-adjusted Death Rate
# 0                         NaN        Alabama  1000000                     55.5
# ...

# %%
data.loc[data['Deaths'] > 15000].index
# Out:
# Int64Index([    0,    52,    53,    54,    55,    56,    57,    58,    59,
#                60,
#             ...
#             10167, 10168, 10169, 10170, 10171, 10172, 10173, 10174, 10175,
#             10176],
#            dtype='int64', length=1283)

# %%
len(data.loc[data['Deaths'] > 15000].index)
# Out:
# 1283

# %% [markdown]
# **Setting values**

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State   Deaths  Age-adjusted Death Rate
# 0                     NaN     Alabama  1000000                     55.5
# 1  Unintentional injuries      Alaska      439                     63.1
# 2  Unintentional injuries     Arizona     4010                     54.2
# 3  Unintentional injuries    Arkansas     1604                     51.8
# 4  Unintentional injuries  California    13213                     32.0

# %%
data.loc[[3,4],'State']
# Out:
# 3      Arkansas
# 4    California
# Name: State, dtype: object

# %%
data.loc[[3,4],'State'] ='Delhi' # # Set value for all items matching the list of labels

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name    State   Deaths  Age-adjusted Death Rate
# 0                     NaN  Alabama  1000000                     55.5
# 1  Unintentional injuries   Alaska      439                     63.1
# 2  Unintentional injuries  Arizona     4010                     54.2
# 3  Unintentional injuries    Delhi     1604                     51.8
# 4  Unintentional injuries    Delhi    13213                     32.0

# %%
data.loc[3] = 10 #  Set value for an entire row

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3    10                                                 10
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name    State   Deaths  Age-adjusted Death Rate
# 0                     NaN  Alabama  1000000                     55.5
# 1  Unintentional injuries   Alaska      439                     63.1
# 2  Unintentional injuries  Arizona     4010                     54.2
# 3                      10       10       10                     10.0
# 4  Unintentional injuries    Delhi    13213                     32.0

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3    10                                                 10
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name    State   Deaths  Age-adjusted Death Rate
# 0                     NaN  Alabama  1000000                     55.5
# 1  Unintentional injuries   Alaska      439                     63.1
# 2  Unintentional injuries  Arizona     4010                     54.2
# 3                      10       10       10                     10.0
# 4  Unintentional injuries    Delhi    13213                     32.0

# %%
data.loc[:,'Deaths'] = 1000 # Set value for an entire column

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3    10                                                 10
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name    State  Deaths  Age-adjusted Death Rate
# 0                     NaN  Alabama    1000                     55.5
# 1  Unintentional injuries   Alaska    1000                     63.1
# 2  Unintentional injuries  Arizona    1000                     54.2
# 3                      10       10    1000                     10.0
# 4  Unintentional injuries    Delhi    1000                     32.0

# %%
data = pd.read_csv("C:/Users/91701/Desktop/Dataset/nchs.csv")

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
help(data.iloc)
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on some value.
#  |  - A tuple of row and column indexes. The tuple elements consist of one of the
#  |    above inputs, e.g. ``(0, 1)``.
#  |
# ...

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.iloc[0]
# Out:
# Year                                                                    2016
# 113 Cause Name             Accidents (unintentional injuries) (V01-X59,Y8...
# Cause Name                                            Unintentional injuries
# State                                                                Alabama
# Deaths                                                                  2755
# Age-adjusted Death Rate                                                 55.5
# Name: 0, dtype: object

# %%
data.iloc[1]
# Out:
# Year                                                                    2016
# 113 Cause Name             Accidents (unintentional injuries) (V01-X59,Y8...
# Cause Name                                            Unintentional injuries
# State                                                                 Alaska
# Deaths                                                                   439
# Age-adjusted Death Rate                                                 63.1
# Name: 1, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %%
data.iloc[[0]]
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name    State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  Alabama    2755                     55.5

# %%
type(data.iloc[[0]])
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[0,3]
# Out:
# 'Alabama'

# %%
data.iloc[:3] # iloc means n-1
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name    State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  Alabama    2755                     55.5
# 1  Unintentional injuries   Alaska     439                     63.1
# 2  Unintentional injuries  Arizona    4010                     54.2

# %%
# Purely integer-location based indexing for selection by position.

# %%
data.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
help(data.insert)
# Out:
# Help on method insert in module pandas.core.frame:
#
# insert(loc: 'int', column: 'Hashable', value: 'Scalar | AnyArrayLike', allow_duplicates: 'bool | lib.NoDefault' = <no_default>) -> 'None' method of pandas.core.frame.DataFrame instance
#     Insert column into DataFrame at specified location.
#
#     Raises a ValueError if `column` is already contained in the DataFrame,
#     unless `allow_duplicates` is set to True.
#
#     Parameters
#     ----------
#     loc : int
#         Insertion index. Must verify 0 <= loc <= len(columns).
#     column : str, number, or hashable object
#         Label of the inserted column.
#     value : Scalar, Series, or array-like
#     allow_duplicates : bool, optional, default lib.no_default
#
#     See Also
#     --------
#     Index.insert : Insert new item by index.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
#     >>> df
#        col1  col2
#     0     1     3
#     1     2     4
# ...

# %%
data.insert(1,'newcol',True)

# %%
data.head()
# Out:
#    Year  newcol                                     113 Cause Name  \
# 0  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.insert(0,'Year',2000, allow_duplicates=True)

# %%
data
# Out:
#        Year  Year  newcol                                     113 Cause Name  \
# 0      2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...   ...     ...                                                ...
# 10291  2000  2003    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2000  2002    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2000  2001    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  2000    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  2000  1999    True  Accidents (unintentional injuries) (V01-X59,Y8...
#
# ...

# %%
# Insert column into DataFrame at specified location.

# %%
data.head()
# Out:
#    Year  Year  newcol                                     113 Cause Name  \
# 0  2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2000  2016    True  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
help(data.pop)
# Out:
# Help on method pop in module pandas.core.frame:
#
# pop(item: 'Hashable') -> 'Series' method of pandas.core.frame.DataFrame instance
#     Return item and drop from frame. Raise KeyError if not found.
#
#     Parameters
#     ----------
#     item : label
#         Label of column to be popped.
#
#     Returns
#     -------
#     Series
#
#     Examples
#     --------
#     >>> df = pd.DataFrame([('falcon', 'bird', 389.0),
#     ...                    ('parrot', 'bird', 24.0),
#     ...                    ('lion', 'mammal', 80.5),
#     ...                    ('monkey', 'mammal', np.nan)],
#     ...                   columns=('name', 'class', 'max_speed'))
#     >>> df
#          name   class  max_speed
#     0  falcon    bird      389.0
#     1  parrot    bird       24.0
#     2    lion  mammal       80.5
#     3  monkey  mammal        NaN
#
#     >>> df.pop('class')
#     0      bird
#     1      bird
#     2    mammal
#     3    mammal
#     Name: class, dtype: object
#
# ...

# %%
data.pop('newcol')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10291    True
# 10292    True
# 10293    True
# 10294    True
# 10295    True
# Name: newcol, Length: 10296, dtype: bool

# %%
data
# Out:
#        Year  Year                                     113 Cause Name  \
# 0      2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...   ...                                                ...
# 10291  2000  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2000  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2000  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  2000  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# ...

# %%
# Return item and drop from frame.

# %%
data.tail() # Return the last n rows.
# Out:
#        Year  Year                                     113 Cause Name  \
# 10291  2000  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2000  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2000  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  2000  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name    State  Deaths  Age-adjusted Death Rate
# 10291  Unintentional injuries  Wyoming     273                     55.1
# 10292  Unintentional injuries  Wyoming     289                     58.1
# 10293  Unintentional injuries  Wyoming     272                     55.5
# 10294  Unintentional injuries  Wyoming     245                     50.8
# 10295  Unintentional injuries  Wyoming     258                     52.8

# %%
help(data.xs)
# Out:
# Help on method xs in module pandas.core.generic:
#
# xs(key: 'IndexLabel', axis: 'Axis' = 0, level: 'IndexLabel' = None, drop_level: 'bool_t' = True) -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Return cross-section from the Series/DataFrame.
#
#     This method takes a `key` argument to select data at a particular
#     level of a MultiIndex.
#
#     Parameters
#     ----------
#     key : label or tuple of label
#         Label contained in the index, or partially in a MultiIndex.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Axis to retrieve cross-section on.
#     level : object, defaults to first n levels (n=1 or len(key))
#         In case of a key partially contained in a MultiIndex, indicate
#         which levels are used. Levels can be referred by label or position.
#     drop_level : bool, default True
#         If False, returns object with same levels as self.
#
#     Returns
#     -------
#     Series or DataFrame
# ...

# %%
data.head()
# Out:
#    Year  Year                                     113 Cause Name  \
# 0  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.xs(0)
# Out:
# Year                                                                    2000
# Year                                                                    2016
# 113 Cause Name             Accidents (unintentional injuries) (V01-X59,Y8...
# Cause Name                                            Unintentional injuries
# State                                                                Alabama
# Deaths                                                                  2755
# Age-adjusted Death Rate                                                 55.5
# Name: 0, dtype: object

# %%
data.xs(1)
# Out:
# Year                                                                    2000
# Year                                                                    2016
# 113 Cause Name             Accidents (unintentional injuries) (V01-X59,Y8...
# Cause Name                                            Unintentional injuries
# State                                                                 Alaska
# Deaths                                                                   439
# Age-adjusted Death Rate                                                 63.1
# Name: 1, dtype: object

# %%
# Return cross-section from the Series/DataFrame.

# %%
help(data.get)
# Out:
# Help on method get in module pandas.core.generic:
#
# get(key, default=None) method of pandas.core.frame.DataFrame instance
#     Get item from object for given key (ex: DataFrame column).
#
#     Returns default value if not found.
#
#     Parameters
#     ----------
#     key : object
#
#     Returns
#     -------
#     value : same type as items contained in object
#
#     Examples
#     --------
#     >>> df = pd.DataFrame(
#     ...     [
#     ...         [24.3, 75.7, "high"],
#     ...         [31, 87.8, "high"],
#     ...         [22, 71.6, "medium"],
#     ...         [35, 95, "medium"],
#     ...     ],
#     ...     columns=["temp_celsius", "temp_fahrenheit", "windspeed"],
#     ...     index=pd.date_range(start="2014-02-12", end="2014-02-15", freq="D"),
#     ... )
#
#     >>> df
#                 temp_celsius  temp_fahrenheit windspeed
#     2014-02-12          24.3             75.7      high
#     2014-02-13          31.0             87.8      high
# ...

# %%
data.head()
# Out:
#    Year  Year                                     113 Cause Name  \
# 0  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2000  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
data.get(['Year','State']) # Get item from object for given key (ex: DataFrame column).
# Out:
#        Year  Year       State
# 0      2000  2016     Alabama
# 1      2000  2016      Alaska
# 2      2000  2016     Arizona
# 3      2000  2016    Arkansas
# 4      2000  2016  California
# ...     ...   ...         ...
# 10291  2000  2003     Wyoming
# 10292  2000  2002     Wyoming
# 10293  2000  2001     Wyoming
# 10294  2000  2000     Wyoming
# 10295  2000  1999     Wyoming
#
# [10296 rows x 3 columns]

# %%
help(data.isin)
# Out:
# Help on method isin in module pandas.core.frame:
#
# isin(values: 'Series | DataFrame | Sequence | Mapping') -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Whether each element in the DataFrame is contained in values.
#
#     Parameters
#     ----------
#     values : iterable, Series, DataFrame or dict
#         The result will only be true at a location if all the
#         labels match. If `values` is a Series, that's the index. If
#         `values` is a dict, the keys must be the column names,
#         which must match. If `values` is a DataFrame,
#         then both the index and column labels must match.
#
#     Returns
#     -------
#     DataFrame
#         DataFrame of booleans showing whether each element in the DataFrame
#         is contained in values.
#
#     See Also
#     --------
#     DataFrame.eq: Equality test for DataFrame.
#     Series.isin: Equivalent method on Series.
# ...

# %%
data.isin(['Alabama']).head()
# Out:
#     Year   Year  113 Cause Name  Cause Name  State  Deaths  \
# 0  False  False           False       False   True   False
# 1  False  False           False       False  False   False
# 2  False  False           False       False  False   False
# 3  False  False           False       False  False   False
# 4  False  False           False       False  False   False
#
#    Age-adjusted Death Rate
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
data.isin([4010]).head()
# Out:
#     Year   Year  113 Cause Name  Cause Name  State  Deaths  \
# 0  False  False           False       False  False   False
# 1  False  False           False       False  False   False
# 2  False  False           False       False  False    True
# 3  False  False           False       False  False   False
# 4  False  False           False       False  False   False
#
#    Age-adjusted Death Rate
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
# Whether each element in the DataFrame is contained in values.

# %%
help(data.groupby)
# Out:
# Help on method groupby in module pandas.core.frame:
#
# groupby(by=None, axis: 'Axis' = 0, level: 'IndexLabel | None' = None, as_index: 'bool' = True, sort: 'bool' = True, group_keys: 'bool | lib.NoDefault' = <no_default>, squeeze: 'bool | lib.NoDefault' = <no_default>, observed: 'bool' = False, dropna: 'bool' = True) -> 'DataFrameGroupBy' method of pandas.core.frame.DataFrame instance
#     Group DataFrame using a mapper or by a Series of columns.
#
#     A groupby operation involves some combination of splitting the
#     object, applying a function, and combining the results. This can be
#     used to group large amounts of data and compute operations on these
#     groups.
#
#     Parameters
#     ----------
#     by : mapping, function, label, or list of labels
#         Used to determine the groups for the groupby.
#         If ``by`` is a function, it's called on each value of the object's
#         index. If a dict or Series is passed, the Series or dict VALUES
# ...

# %%
data = pd.read_csv("C:/Users/91701/Desktop/Dataset/nchs.csv")

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
data.groupby(['Deaths']).mean()
# Out:
# C:\Users\91701\AppData\Local\Temp\ipykernel_19828\3655882226.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Deaths']).mean()
#            Year  Age-adjusted Death Rate
# Deaths
# 21       2007.0                     4.70
# 23       2002.0                     5.45
# 24       2000.0                     9.55
# 28       2003.0                     8.40
# 29       2009.0                     4.40
# ...         ...                      ...
# 2515458  2011.0                   741.30
# 2543279  2012.0                   732.80
# 2596993  2013.0                   731.90
# 2626418  2014.0                   724.60
# 2712630  2015.0                   733.10
#
# [5741 rows x 2 columns]

# %%
data = pd.read_csv("C:/Users/91701/Desktop/Dataset/nchs.csv")

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10296 non-null  int64
#  1   113 Cause Name           10296 non-null  object
#  2   Cause Name               10296 non-null  object
#  3   State                    10296 non-null  object
#  4   Deaths                   10296 non-null  int64
#  5   Age-adjusted Death Rate  10296 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 482.8+ KB

# %%
#What is the total number of records in the dataset?

# %%
data.shape
# Out:
# (10296, 6)

# %% [raw]
# #Approximately 10296 death cases were recorded in different U.S. states.Now let’s clean the data to find the number of death causes in thedata set

# %%
#What were the causes of death in this dataset?

# %%
data.columns
# Out:
# Index(['Year', '113 Cause Name', 'Cause Name', 'State', 'Deaths',
#        'Age-adjusted Death Rate'],
#       dtype='object')

# %%
data[['113 Cause Name','Cause Name']]
# Out:
#                                           113 Cause Name  \
# 0      Accidents (unintentional injuries) (V01-X59,Y8...
# 1      Accidents (unintentional injuries) (V01-X59,Y8...
# 2      Accidents (unintentional injuries) (V01-X59,Y8...
# 3      Accidents (unintentional injuries) (V01-X59,Y8...
# 4      Accidents (unintentional injuries) (V01-X59,Y8...
# ...                                                  ...
# 10291  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name
# 0      Unintentional injuries
# 1      Unintentional injuries
# 2      Unintentional injuries
# 3      Unintentional injuries
# 4      Unintentional injuries
# ...                       ...
# 10291  Unintentional injuries
# ...

# %%
data['113 Cause Name'].unique()
# Out:
# array(['Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#        'All Causes', "Alzheimer's disease (G30)",
#        'Malignant neoplasms (C00-C97)',
#        'Chronic lower respiratory diseases (J40-J47)',
#        'Diabetes mellitus (E10-E14)',
#        'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#        'Influenza and pneumonia (J09-J18)',
#        'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
#        'Cerebrovascular diseases (I60-I69)',
#        'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)'],
#       dtype=object)

# %%
data['Cause Name'].unique()
# Out:
# array(['Unintentional injuries', 'All causes', "Alzheimer's disease",
#        'Cancer', 'CLRD', 'Diabetes', 'Heart disease',
#        'Influenza and pneumonia', 'Kidney disease', 'Stroke', 'Suicide'],
#       dtype=object)

# %%
len(data['Cause Name'].unique())
# Out:
# 11

# %%
# Both are same, so we are removing one column.

# %%
causes=data['Cause Name'][data['Cause Name']!='All causes'].unique()

# %%
causes
# Out:
# array(['Unintentional injuries', "Alzheimer's disease", 'Cancer', 'CLRD',
#        'Diabetes', 'Heart disease', 'Influenza and pneumonia',
#        'Kidney disease', 'Stroke', 'Suicide'], dtype=object)

# %%
len(causes)
# Out:
# 10

# %%
#As shown, there are 10 death causes according to the loaded data set

# %%
#What was the total number of deaths in the UnitedStates from 1999 to 2015?

# %%
data.Deaths.sum()
# Out:
# 157803463

# %%
dyear = data.groupby('Year').sum()
# Out:
# C:\Users\91701\AppData\Local\Temp\ipykernel_19828\3484319549.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dyear = data.groupby('Year').sum()

# %%
dyear
# Out:
#        Deaths  Age-adjusted Death Rate
# Year
# 1999  8594450                  82092.1
# 2000  8611090                  81348.2
# 2001  8631566                  80287.5
# 2002  8724520                  80067.7
# 2003  8720806                  78948.7
# 2004  8523496                  75728.2
# 2005  8675996                  75942.4
# 2006  8561880                  73598.8
# 2007  8540026                  72093.0
# 2008  8689930                  72015.3
# 2009  8551328                  69547.8
# 2010  8641568                  69346.4
# 2011  8769558                  68672.9
# 2012  8839734                  67660.4
# 2013  9014608                  67556.0
# 2014  9129652                  67277.1
# 2015  9451294                  68288.4
# 2016  9131961                  67689.2

# %%
dyear["Deaths"].plot(title="Death per year from 1999-2015")
# Out:
# <Axes: title={'center': 'Death per year from 1999-2015'}, xlabel='Year'>

# %%
#Top Ten States with the Highest Number of Deaths in the United States

# %%
data1 = data[data["State"] !="United States"]

# %%
data1
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
data2 = data1.groupby("State").sum()
# Out:
# C:\Users\91701\AppData\Local\Temp\ipykernel_19828\577747620.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2 = data1.groupby("State").sum()

# %%
data2
# Out:
#                         Year   Deaths  Age-adjusted Death Rate
# State
# Alabama               397485  1510931                  30446.7
# Alaska                397485   110361                  24462.6
# Arizona               397485  1471757                  23278.0
# Arkansas              397485   929634                  29442.7
# California            397485  7694563                  22415.2
# Colorado              397485   973746                  22575.7
# Connecticut           397485   927612                  21981.2
# Delaware              397485   238935                  25367.4
# District of Columbia  397485   160361                  27437.4
# Florida               397485  5512136                  23067.3
# Georgia               397485  2182235                  27467.6
# Hawaii                397485   300668                  19696.3
# Idaho                 397485   351070                  24038.2
# Illinois              397485  3299528                  25044.8
# ...

# %%
data2.sort_values("Deaths", ascending=False ,inplace = True)

# %%
data2.head(10)
# Out:
#                   Year   Deaths  Age-adjusted Death Rate
# State
# California      397485  7694563                  22415.2
# Florida         397485  5512136                  23067.3
# Texas           397485  5192340                  25494.4
# New York        397485  4889235                  22889.7
# Pennsylvania    397485  4069680                  25688.7
# Ohio            397485  3501123                  27134.4
# Illinois        397485  3299528                  25044.8
# Michigan        397485  2839241                  26291.2
# North Carolina  397485  2447232                  26618.7
# New Jersey      397485  2267451                  23425.4

# %%
data2["Deaths"].head(10).plot.bar(title= "Top tenstates with highest death number \n 1999-2015 ")
# Out:
# <Axes: title={'center': 'Top tenstates with highest death number \n 1999-2015 '}, xlabel='State'>
